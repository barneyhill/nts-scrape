# %%
import xml.etree.ElementTree as ET
import json
import gzip
from tqdm import tqdm
import hashlib

def hash_track(artist, title):
    return hashlib.md5(f"{artist.lower()} - {title.lower()}".encode()).hexdigest()

def match_discogs_id(xml_gz_file, json_data):

    track_dict = {}
    for show in json_data:
        for track in json_data[show]['tracks']:
            track_hash = hash_track(track['artist'], track['title'])
            track_dict[track_hash] = track


    with gzip.open(xml_gz_file, 'rt') as f:
        for event, elem in tqdm(ET.iterparse(f, events=('end',)), desc="Matching Discogs IDs"):
            if elem.tag == 'release':
                xml_artist = elem.find('artists/artist/name').text
                discogs_id = elem.get('id')

                # Get the list of track titles in the XML file
                xml_track_titles = [track.find('title').text for track in elem.findall('tracklist/track')]
                
                # Iterate over the xml_track_titles and check if the hash is in track_dict
                for title in xml_track_titles: 
                    if xml_artist is None or title is None:
                        continue
                    track_hash = hash_track(xml_artist, title)
                    if track_hash in track_dict:
                        track_dict[track_hash]['discogs_id'] = discogs_id

                elem.clear()  # free up memory

    # return updated json_data
    return track_dict

# Load json data
with open('../data/nts_29_7_23_tracklists.json', 'r') as f:
    data = json.load(f)

# Update json data with discogs_id
track_dict = match_discogs_id('/Users/barneyh/Downloads/discogs_20230601_releases.xml.gz', data)
# Out:
# Matching Discogs IDs: 2729598337it [33:26, 1360226.13it/s]

# %%
for show in data.values():
    for track in show['tracks']:
        track_id = track['uid']
        if track_id in track_dict and 'discogs_id' in track_dict[track_id]:
            track['discogs_id'] = track_dict[track_id]['discogs_id']


with open('../data/nts_29_7_23_w_discogs_tracklists.json', 'w') as outfile:
    json.dump(data, outfile)

# %%
total=0
for track in track_dict.values():
    if track.get('discogs_id') != None and track['linked']:
        total+=1

print(total)
# Out:
# 32805

# %%
get_release_count('/Users/barneyh/Downloads/discogs_20230601_releases.xml.gz')
# Out:
# 5240500it [00:03, 1341695.83it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 get_release_count('/Users/barneyh/Downloads/discogs_20230601_releases.xml.gz')
#
# Cell In[11], line 9, in get_release_count(xml_gz_file)
#       7 release_count = 0
#       8 with gzip.open(xml_gz_file, 'rt') as f:
# ----> 9     for _, elem in tqdm(ET.iterparse(f)):
#      10         if elem.tag == 'release':
#      11             release_count += 1
#
# File ~/.conda/envs/nts/lib/python3.11/site-packages/tqdm/std.py:1178, in tqdm.__iter__(self)
#    1175 time = self._time
#    1177 try:
# -> 1178     for obj in iterable:
#    1179         yield obj
#    1180         # Update and possibly print the progressbar.
#    1181         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/.conda/envs/nts/lib/python3.11/xml/etree/ElementTree.py:1254, in iterparse.<locals>.iterator(source)
#    1252     if not data:
#    1253         break
# -> 1254     pullparser.feed(data)
#    1255 root = pullparser._close_and_return_root()
#    1256 yield from pullparser.read_events()
#
# File ~/.conda/envs/nts/lib/python3.11/xml/etree/ElementTree.py:1292, in XMLPullParser.feed(self, data)
#    1290 if data:
#    1291     try:
# -> 1292         self._parser.feed(data)
#    1293     except SyntaxError as exc:
#    1294         self._events_queue.append(exc)
#
# KeyboardInterrupt:

# %%
data
# Out:
# {'emotional-16th-july-2023': {'url': '/shows/emotional/episodes/emotional-16th-july-2023',
#   'name': 'All Trades w/ Chuggy',
#   'loc': 'London',
#   'date': '16.07.23',
#   'tracks': [{'uid': '439aa1df54c747e7c16038f8844b8fe0',
#     'artist': 'Fredde Viadukt',
#     'title': 'Marvel Of Miracles',
#     'linked': False},
#    {'uid': 'cbb1b70abc83b534d46fc3dae3c2ba5c',
#     'artist': 'Kosmoksen Errako',
#     'title': 'Jolkottelevat',
#     'linked': False},
#    {'uid': '55788bfa9fcf9b2f47f4f47885f23eb3',
#     'artist': 'Nyati Mayi & The Astral Synth Transmitters',
#     'title': 'Lolokele',
#     'linked': False},
#    {'uid': '967395b7ef8f0989dfb30a445bb2399e',
#     'artist': 'Big Daddy',
#     'title': "Cupid's Itch ",
#     'linked': False},
#    {'uid': '5700ec1977fef581671b5c8ffa677aa6',
#     'artist': "Jade, Lil' Rachett, VAZ",
#     'title': "Keep On Risin' (No Rap Version)",
#     'linked': False},
#    {'uid': '26408a41e0a3fd869cc6aed18c298b63',
#     'artist': 'By Chance',
#     'title': 'Revenge',
#     'linked': False},
#    {'uid': '6a52484c61ef59b983792d3fe64c6b79',
#     'artist': 'Die Radierer',
#     'title': 'Batman',
#     'linked': False},
#    {'uid': '897be9eb42f4fbe382247c66e0c3b6fa',
#     'artist': 'Sagat',
#     'title': 'Money Magic',
#     'linked': False},
#    {'uid': '94339c5b3450d123ec1e7aeeb76ca4cc',
#     'artist': 'Tapes',
#     'title': 'Parrot Samba',
#     'linked': False},
#    {'uid': '56b3399eb21a5cddccc8afb31c10a857',
#     'artist': 'Mike Brooks',
#     'title': 'On The Ice (Version)',
#     'linked': False},
#    {'uid': '1a0f5784dd82cfb25d28b370ca3cd23d',
#     'artist': 'Prince Jazzbo',
#     'title': '333 (Version)',
#     'linked': False},
#    {'uid': 'a5412e5a9aa6bf2ef3b17f00998d289f',
#     'artist': 'Jay Glass Dub',
#     'title': 'Skull Dub',
#     'linked': False},
#    {'uid': 'c1ff0fcea70f4482fc16809affe54fdd',
#     'artist': 'Jesse Futerman Ft. Beverly Glenn-Copeland',
#     'title': 'Luckey (Peaking Lights Remix)',
#     'linked': False},
#    {'uid': '3a388d763feb729d49be20034c1b1b6b',
#     'artist': '33103402',
#     'title': 'Labyrinths & Coral Caves',
#     'linked': False},
#    {'uid': '78368856d21a255a3a28ae31ba5b2c38',
#     'artist': 'N90C',
#     'title': 'Entity',
#     'linked': False},
#    {'uid': 'c5a471de1136f0d6e1b5e769cf3325a2',
#     'artist': 'Hari Peirson',
#     'title': 'Trippy Too',
#     'linked': False},
#    {'uid': '41faad108d440270520d913098c0719c',
#     'artist': 'Remotif',
#     'title': '3AM In The Mobius Trip Club',
#     'linked': False},
#    {'uid': '79d0e5b02647bfc7d7b1a1608ed2851d',
#     'artist': 'Digital Distortion',
#     'title': 'Take Your Soul',
#     'linked': False},
#    {'uid': 'd2757a23c04400cc0450d6556fae72fb',
#     'artist': 'Underground Posse',
#     'title': 'Check It Out (Smooth Version)',
#     'linked': False},
#    {'uid': 'bac0f2ddbba1df5f57d49fa30e889ca9',
#     'artist': 'De Lux (Remix by Idjut Boys)',
#     'title': "What's Life (Idjut Boys Dub Remix)",
#     'linked': False}]},
#  'aerial-roots-16th-july-2023': {'url': '/shows/aerial-roots/episodes/aerial-roots-16th-july-2023',
#   'name': 'Aerial Roots: Summer Jams',
#   'loc': 'Manchester',
#   'date': '16.07.23',
#   'tracks': [{'uid': 'f9e12263c87a2b8db45714df2ebd1352',
#     'artist': 'Stevie Wonder',
#     'title': 'All I Do',
#     'linked': True},
#    {'uid': 'cedfe26a62fd5bf1cef2dcfebf2fa6c4',
#     'artist': 'Mary Jane Girls',
#     'title': 'All Night Long',
#     'linked': True},
#    {'uid': 'f19df2aead9d0d61f45add137edaea3b',
#     'artist': 'Janet Kay',
#     'title': 'Silly Games',
#     'linked': True},
#    {'uid': '4060010d4bd8af51e4a7293db280c5d7',
#     'artist': 'Marvin Gaye',
#     'title': 'Mercy Mercy Me (The Ecology)',
#     'linked': True},
#    {'uid': '46e051b398fc0fd9ff8e61bd6028e0c4',
#     'artist': 'ENNY',
#     'title': 'Charge It',
#     'linked': False},
#    {'uid': '1349c3a20a51fc9f4a28dbfd498b92c4',
#     'artist': 'Terri Walker, MC DRS',
#     'title': 'Rhythm of Change',
#     'linked': False},
#    {'uid': '6d6c1ca91e6256c9c1adcea0a4b759ed',
#     'artist': 'Shanique Marie',
#     'title': 'Breezy Day',
#     'linked': False},
#    {'uid': 'c99179f4b96e7dd9834d4ff89e92332f',
#     'artist': 'Tweet',
#     'title': 'Boogie 2Nite',
#     'linked': True},
#    {'uid': '595d5aa29f61efe4c02541eb96078d88',
#     'artist': 'Janelle Monáe feat. Seun Kuti + Egypt 80',
#     'title': 'Float',
#     'linked': True},
#    {'uid': '416b9f2fc734c3333b2f99127187edb9',
#     'artist': 'Kamaiyah',
#     'title': 'Ain’t Going Home Tonight',
#     'linked': False},
#    {'uid': '9587b33e88ab52bb8da979b40b9c3e25',
#     'artist': 'Novelist',
#     'title': 'Straight Riddim',
#     'linked': False},
#    {'uid': '1705d1d8ae515ef2428a2368ea984454',
#     'artist': 'J Hus feat. Locz',
#     'title': 'Dubai',
#     'linked': True},
#    {'uid': '3aab8dedd295db27b4a8da938e791936',
#     'artist': 'Dungeon Family',
#     'title': "Rollin'",
#     'linked': True},
#    {'uid': 'd4850b9c452723e3f81ff9aeafc6df49',
#     'artist': 'Mario',
#     'title': 'Just A Friend 2002',
#     'linked': False},
#    {'uid': 'da555cfc9ebc66c1cdffbe077e99ad3e',
#     'artist': 'Burna Boy',
#     'title': "Sittin' On Top Of The World",
#     'linked': True},
#    {'uid': 'e8adffa1de12e7662bf266c68bccbe50',
#     'artist': 'Jorja Smith',
#     'title': 'Little Things (Extended Mix)',
#     'linked': True}]},
#  'psychedelic-ensemble-16th-july-2023': {'url': '/shows/psychedelic-ensemble/episodes/psychedelic-ensemble-16th-july-2023',
#   'name': 'LIVE AT THE CLINIC W/ domtavlor',
#   'loc': 'London',
#   'date': '16.07.23',
#   'tracks': [{'uid': 'fe73301172b674b7bfa6993569f2af3f',
#     'artist': 'Bedwetter',
#     'title': 'Fondly Eulogizing Sleep',
#     'linked': True},
#    {'uid': 'c60fcf59ea69ce2382bc026dce4818e5',
#     'artist': 'Also (Aloisius & Jaso)',
#     'title': 'Another Forfeit',
#     'linked': False},
#    {'uid': '0797fc3e5846796998f75b27d45c936b',
#     'artist': 'Lemur Echo & Joe Beard',
#     'title': 'Inside The Statue (Demo)',
#     'linked': False},
#    {'uid': 'd24fd67b9fdfdf47558bf84a83722751',
#     'artist': 'Dijon',
#     'title': 'Did You See It',
#     'linked': False},
#    {'uid': '24b4c83078fe4098984007792fed897b',
#     'artist': 'Ballaké Sissoko',
#     'title': 'Kabou',
#     'linked': False},
#    {'uid': '38f9cca2aaddaded36de6242f3e8f3fe',
#     'artist': 'Yonqi & ZekeUltra',
#     'title': 'RENT FREE',
#     'linked': False},
#    {'uid': '1eff093792c6d6be2040861c6c6043a8',
#     'artist': 'Alex G',
#     'title': 'In Love',
#     'linked': False},
#    {'uid': 'daadc8399229f29a65f5f214fb0a15d0',
#     'artist': 'Knxwledge',
#     'title': 'Pushit.',
#     'linked': True},
#    {'uid': 'c75db26b40ef3fade5b1cc1b9d9bc547',
#     'artist': 'Sideshow',
#     'title': 'Soul At War (Feat. Navy Blue)',
#     'linked': False},
#    {'uid': 'aafdedcd9e0838e724145860f5da73d2',
#     'artist': 'Domtavlor & Swordbearer',
#     'title': 'Ladbrokes (Demo)',
#     'linked': False},
#    {'uid': '62b61a197c7a50bea93005340090d622',
#     'artist': 'Mulatu Astatke',
#     'title': 'Tezeta (Domtavlor Rework)',
#     'linked': False},
#    {'uid': 'e5bd837cb4188732cba587cc439653e8',
#     'artist': 'King Krule',
#     'title': 'My Rifle, My Pony And Me (Dean Martin Cover)',
#     'linked': False},
#    {'uid': '67c0fd0c645f03b4b4753d5e178c9803',
#     'artist': 'Dr. Yen Lo',
#     'title': 'Day 1125',
#     'linked': False},
#    {'uid': '4f941187f954b66c06a4bcfce0d1a089',
#     'artist': 'Mary Sue',
#     'title': 'Deer and the Crocodile',
#     'linked': False},
#    {'uid': 'a021ca0a06a9c0e0f5e13fb9a13851b2',
#     'artist': 'Domtavlor & Lemur Echo',
#     'title': 'The Lounge (Demo)',
#     'linked': False},
#    {'uid': '9220723c6314f05d3bdde39ab36fdcf1',
#     'artist': 'Vegyn',
#     'title': 'So Much Time',
#     'linked': True},
#    {'uid': 'b7f9ea11ba25f520312002e74fadbdc6',
#     'artist': 'Domtavlor & RJ',
#     'title': 'Weight Lift (Instrumental Rework)',
#     'linked': False},
#    {'uid': '2f92ae811ffcd9b2e479541feb7d2a67',
#     'artist': 'Rosier',
#     'title': 'Wait Up (Feat. Joe Beard, Domtavlor And Bongani) (Demo)',
#     'linked': False},
#    {'uid': '387996ac244d49ff5632d08e870b9093',
#     'artist': 'Martin Rev',
#     'title': 'Secret Teardrops',
#     'linked': True},
#    {'uid': 'b3264dfeb547568776742cba5871c8db',
#     'artist': 'Niontay',
#     'title': 'Thank Allah',
#     'linked': True}]},
#  'midnight-marauders-16th-july-2023': {'url': '/shows/midnight-marauders/episodes/midnight-marauders-16th-july-2023',
#   'name': 'Midnight Marauders w/ Marshmello',
#   'loc': 'London',
#   'date': '16.07.23',
#   'tracks': [{'uid': 'b1b22fed957cb7b74642331eeabbe1f6',
#     'artist': 'Mental Remedy',
#     'title': 'Omamiuda (Prayer For Japan Version)',
#     'linked': False},
#    {'uid': '622d8ed18903845abec433a01949dfe9',
#     'artist': 'Birds Of Rhythm',
#     'title': 'Bird Island',
#     'linked': False},
#    {'uid': '202b6db77307af2c5bed56efca0ca576',
#     'artist': 'Warriors Of The Dystotheque',
#     'title': 'Beachside Drive',
#     'linked': False},
#    {'uid': '1fba5bcbf68d5e9aff983b397d6d5ec4',
#     'artist': 'Warriors Of The Dystotheque Ft. Ashley Slater',
#     'title': 'Be My Star',
#     'linked': False},
#    {'uid': '99eae0a956897061ecf8345b52d819f9',
#     'artist': 'Robert Cox',
#     'title': 'Embers',
#     'linked': False},
#    {'uid': 'ebd8a486a6c1e932dda976967cbdf2c0',
#     'artist': 'Matthias Vogt & Sato',
#     'title': 'Carmel',
#     'linked': False},
#    {'uid': 'a5814699991f3b95f4a0833d2e76b5f8',
#     'artist': 'TM Shuffle & Tapani Rinne',
#     'title': 'Nighttime (Summernight Version)',
#     'linked': False},
#    {'uid': '7416441dfe181a45755cfda4a9b10262',
#     'artist': 'Dlle Jlle-Balearic Incarnation',
#     'title': 'Todd Terje’s Extra Dll Mix',
#     'linked': False},
#    {'uid': '1d20f4e1b78701cdad98fc9755675313',
#     'artist': 'Moon Rocket Feat. Paula',
#     'title': 'Reciprocity (Main Mix)',
#     'linked': False},
#    {'uid': 'b484178ba21e838a43c3ca50b2c4d810',
#     'artist': 'Osunlade Feat. Maiya James',
#     'title': 'Same Thing (Atjazz Remix)',
#     'linked': False},
#    {'uid': 'e7599443dddab2d259a3717b24cea879',
#     'artist': 'Stephanie Mills (Remix by The Layabouts)',
#     'title': 'Free (The Layabouts Vocal Mix)',
#     'linked': False},
#    {'uid': '73e221383de816fdb4552d62e38bfece',
#     'artist': 'Malik Hendricks',
#     'title': 'The Money Dance',
#     'linked': True},
#    {'uid': '18f86c891e2adc6ff40fad9818895d88',
#     'artist': 'Steven Julien & Kyle Hall',
#     'title': 'Page 3 (Feat K-15)',
#     'linked': False},
#    {'uid': '6125c983c6a62ebd50fd8bb21e4ff5cb',
#     'artist': 'BALMR',
#     'title': 'Paths Unknown',
#     'linked': False},
#    {'uid': '4f64cce9f17c6492d92a510fe901c6d5',
#     'artist': 'SHOUSE',
#     'title': 'Your Love Original Mix',
#     'linked': False},
#    {'uid': '5fda934f2845ec4a234e75811115efcc',
#     'artist': 'Jessy Lanza',
#     'title': 'Midnight Ontario',
#     'linked': True},
#    {'uid': '520015ef8d64cc73e750e4b3076e570e',
#     'artist': 'Tools & Figs',
#     'title': 'Blackout',
#     'linked': True},
#    {'uid': 'de9847295fb96e28f88656cc3b479210',
#     'artist': 'Joe Masunga',
#     'title': 'Nwananga Washanesera',
#     'linked': False},
#    {'uid': '13b5f79277139ce735b23aaacf6ecded',
#     'artist': 'Chicco',
#     'title': 'Chomesa',
#     'linked': False},
#    {'uid': '27fec0c8f5d2a360372eb12a985480f4',
#     'artist': 'Black Moses',
#     'title': "Crocodile's Rocl",
#     'linked': False},
#    {'uid': 'f0f5ec04604273cb1ea2b7a108ecd98c',
#     'artist': 'Sky Jinx',
#     'title': 'Pusa Twala',
#     'linked': False}]},
#  'thereignset-16th-july-2023': {'url': '/shows/thereignset/episodes/thereignset-16th-july-2023',
#   'name': 'The Reign Set W/ ZETA ZETA LIVE',
#   'loc': 'London',
#   'date': '16.07.23',
#   'tracks': [{'uid': 'af305ede8befbbb632af8becbed41f93',
#     'artist': 'soFa elsewhere',
#     'title': 'The Dream',
#     'linked': False},
#    {'uid': '87016faf2d9a562808d7a441f284a34a',
#     'artist': 'Marianne Faithfull, Sly And Robbie (Remix by Faultline)',
#     'title': 'Lola R. For Ever (Faultline Remix)',
#     'linked': False},
#    {'uid': '30d74f4257a2199e12794dd93e54af83',
#     'artist': 'Peaking Lights',
#     'title': 'Live Love',
#     'linked': True},
#    {'uid': 'c43ed6d45f71901bc427779cfb9a0e04',
#     'artist': 'Unknown',
#     'title': 'Unknown',
#     'linked': False},
#    {'uid': 'e584de2ed6b4a5c20faf9499de1bc6eb',
#     'artist': 'Simulant',
#     'title': 'Musical Box',
#     'linked': True},
#    {'uid': '12364c0630eeead8941c5c660df2ecf6',
#     'artist': 'Live',
#     'title': 'Session',
#     'linked': True},
#    {'uid': 'e6f47c1809f6cc97ab3ad4dc1cbd53a2',
#     'artist': 'Zeta Zeta',
#     'title': 'All Day All Night',
#     'linked': False},
#    {'uid': '728d969629df48c293fd44006cc0f833',
#     'artist': 'Zeta Zeta',
#     'title': 'Jukebox',
#     'linked': False},
#    {'uid': 'a1e05ade57ded6dda1e30f09d8e79988',
#     'artist': 'Zeta Zeta',
#     'title': 'Cola Cubes',
#     'linked': False},
#    {'uid': 'c43ed6d45f71901bc427779cfb9a0e04',
#     'artist': 'Unknown',
#     'title': 'Unknown',
#     'linked': False}]},
#  'kit-grill-16th-july-2023': {'url': '/shows/kit-grill/episodes/kit-grill-16th-july-2023',
#   'name': 'Kit Grill',
#   'loc': 'London',
#   'date': '16.07.23',
#   'tracks': [{'uid': '2ce4f7db6a253d20594a922fd71cf508',
#     'artist': 'Anohi',
#     'title': 'It Must Change',
#     'linked': False},
#    {'uid': '8a5c0135169d0ac353fc45b32677f3c8',
#     'artist': 'Fizzy Veins',
#     'title': 'Drop The Hood',
#     'linked': False},
#    {'uid': '9dc05241f4ef1a6cba355e372f0a992b',
#     'artist': 'Night Lands',
#     'title': 'Looking Up',
#     'linked': False},
#    {'uid': '3b3a488dca6799d81842130a979bcd16',
#     'artist': 'Pigbaby',
#     'title': "Why Don't You Stay, For A Moment",
#     'linked': True},
#    {'uid': '6ac7a2655444b8b20e1d0b40c63d5503',
#     'artist': 'Dominique Lawalrée',
#     'title': 'Flight 3.0.5.',
#     'linked': True},
#    {'uid': '8fa1daeaaf381426eac0db7ca2fbcb34',
#     'artist': 'Maxime Dénucléariser',
#     'title': 'Infinite End',
#     'linked': False},
#    {'uid': 'd25993f2e0d1157ed8c0556c160f5cd8',
#     'artist': 'Durutti Column',
#     'title': 'Abuse',
#     'linked': True},
#    {'uid': '9e54a7931e242f63ebcd2c36cc07a86a',
#     'artist': 'Pavement',
#     'title': 'Box Elder',
#     'linked': True},
#    {'uid': '2cdd68f2573318dc4b79a1b4ea68db1e',
#     'artist': 'Svitlana Nianio',
#     'title': 'Ipomoea',
#     'linked': False},
#    {'uid': '4e6a4c296178edc5cdb518cecb15f8c5',
#     'artist': 'Orchestre Volta-Jazz',
#     'title': 'Djougou Toro',
#     'linked': True},
#    {'uid': '85f605367771a861fbf6df6185a2b5a6',
#     'artist': 'Brown Spirits',
#     'title': 'Who’s At The Door',
#     'linked': False},
#    {'uid': 'fd6e87ded13e2638df8b1a49bec67062',
#     'artist': 'Black Merda',
#     'title': 'Windsong',
#     'linked': False},
#    {'uid': '6f0ef8befbc0e86fcd6910a0169f53f0',
#     'artist': 'Glenn Jones',
#     'title': 'Forsythia',
#     'linked': False}]},
#  'hotmess-16th-july-2023': {'url': '/shows/hotmess/episodes/hotmess-16th-july-2023',
#   'name': 'Hot Mess',
#   'loc': 'London',
#   'date': '16.07.23',
#   'tracks': [{'uid': 'c261c3628b587c9815173dc9f3d03326',
#     'artist': 'Fuubutsushi',
#     'title': 'Bolted Orange',
#     'linked': False},
#    {'uid': '27fa98b2918c57b48c31f18630fb3309',
#     'artist': 'B. Beat Girls',
#     'title': 'For The Same Man (92 Version)',
#     'linked': False},
#    {'uid': '3cf139572421232ed6d07e1e39aca654',
#     'artist': 'The Jonzun Crew',
#     'title': 'Pak Man (Look Out For The OVC)',
#     'linked': False},
#    {'uid': 'd8a134e8b71c24b849459ef11aecc943',
#     'artist': 'Sonic Youth feat. Chuck D.',
#     'title': 'Kool Thing',
#     'linked': True},
#    {'uid': '4efec3118ba365f8d7d968b962318f28',
#     'artist': 'Yoko Ono',
#     'title': 'Walking On Thin Ice',
#     'linked': True},
#    {'uid': 'def69757fc82a6da9f42ac566fae5d6a',
#     'artist': 'Folk Implosion',
#     'title': 'Natural One',
#     'linked': False},
#    {'uid': '4b83b678a81565529ecc1941aff724d4',
#     'artist': 'Tortoise',
#     'title': 'Eros',
#     'linked': False},
#    {'uid': '9f85a837e838ed26d39f2c3fcccf4320',
#     'artist': 'The Breeders',
#     'title': 'Go Man Go',
#     'linked': False},
#    {'uid': 'b2cee75cae0bde342ef3781efeaf8235',
#     'artist': 'Julie Doiron',
#     'title': 'Consolation Prize',
#     'linked': False},
#    {'uid': '7599af1321df208bdbf2243f2678df49',
#     'artist': 'Sammy',
#     'title': 'Hi Fi Kilers',
#     'linked': False},
#    {'uid': '8aeb529144a696dc5490c7702e750ef6',
#     'artist': 'Rose City Band',
#     'title': 'Empty Bottles',
#     'linked': True},
#    {'uid': '2f3b511f0e25e28dbce74775ae42860f',
#     'artist': 'Bonnie "Prince" Billy',
#     'title': 'Crazy Blue Bells',
#     'linked': False},
#    {'uid': 'a822f0f6103704f1977f7d8ad6304a2e',
#     'artist': 'Joanna Sternberg',
#     'title': "I've Got Me",
#     'linked': False},
#    {'uid': 'be9822f289dd391159a8da45bfa44e31',
#     'artist': 'William Tyler',
#     'title': 'The Great Unwind',
#     'linked': False}]},
#  'sophia-zhuravkova-16th-july-2023': {'url': '/shows/sophia-zhuravkova/episodes/sophia-zhuravkova-16th-july-2023',
#   'name': 'SOPHIA ZHURAVKOVA',
#   'loc': None,
#   'date': '16.07.23',
#   'tracks': [{'uid': 'f099fbfe689cdb0b4e90dbb0d8d88471',
#     'artist': 'Elijah Knutsen',
#     'title': 'Wonder How',
#     'linked': False},
#    {'uid': '1667d6066d78ffc7d98cadda9f7b387f',
#     'artist': 'Cass.',
#     'title': 'Daydream Daydream',
#     'linked': False},
#    {'uid': '723d35b3e724d447d47f8f94285acc33',
#     'artist': "L'eoscombu Couti",
#     'title': 'https://www.google.com/maps/@65.496568,-18.132248,3a,75y,343.38h,73.52t/data=!3m4!1e1!3m2!1s4Qh_OPnq9KvG-AI4i4SRCw!2e0',
#     'linked': False},
#    {'uid': 'a59ccf49a9f7a5c3d2e1f714ff468b1b',
#     'artist': 'Sofie Birch',
#     'title': 'Willness',
#     'linked': True},
#    {'uid': '1862f1579b4e6d6099eac1ce1edf33d6',
#     'artist': 'Dolphins Into The Future',
#     'title': 'Onset - Beyond Clouds',
#     'linked': False},
#    {'uid': 'b41bc0c8bb7b75f85750b0df3c49fee4',
#     'artist': 'UNITEDSTATESOF',
#     'title': 'Quiescence',
#     'linked': False},
#    {'uid': '6c233cdd12fc4968d68368875b8d99bd',
#     'artist': 'Dravier',
#     'title': 'meditation tool',
#     'linked': False},
#    {'uid': 'ab4ab3478f200322434bafe7fa9675ca',
#     'artist': 'J.D. Emmanuel',
#     'title': 'Sunrise On A Tibetan Hillside',
#     'linked': True},
#    {'uid': '2fa896a866860bd43db655e16e04afd1',
#     'artist': 'Iasos',
#     'title': 'Cloud Prayer',
#     'linked': True},
#    {'uid': '17d024f0af4049928b48a8165b6646b9',
#     'artist': 'Kevin Drumm',
#     'title': '0.75ed',
#     'linked': False},
#    {'uid': 'e92cd20637c0b78be0ed789dae1db503',
#     'artist': 'Abandoned Bees',
#     'title': 'Dust',
#     'linked': True},
#    {'uid': '50d66a6e9db33a2d74d9ecfda22070a4',
#     'artist': 'Ewer',
#     'title': 'Lotus Pond',
#     'linked': False}]},
#  'mutualism-15th-july-2023': {'url': '/shows/mutualism/episodes/mutualism-15th-july-2023',
#   'name': 'Mutualism w/ Boosterhooch & Lewis Lowe',
#   'loc': 'Manchester',
#   'date': '15.07.23',
#   'tracks': [{'uid': '8d01989131b1a2b1b0cbef7fe6806b83',
#     'artist': '???',
#     'title': '???',
#     'linked': False},
#    {'uid': '1ec03c7f51e95a6b0c204135d6c750f4',
#     'artist': 'Metrist',
#     'title': 'Bputch',
#     'linked': False},
#    {'uid': 'eaaf3d6079aec9d4dd895a0e55f735bb',
#     'artist': 'Prest',
#     'title': 'Black Lotus',
#     'linked': True},
#    {'uid': 'ac399a2bc03f61f2aeff46e0cec20264',
#     'artist': 'Hngwy',
#     'title': 'Quigonegin',
#     'linked': False},
#    {'uid': 'b7a6797f0d564e84afb849e10285c5d8',
#     'artist': 'Significant Other',
#     'title': 'Cellar One',
#     'linked': True},
#    {'uid': '534a6dff2a7fa97e941411e343c2a651',
#     'artist': 'Son Of Phillip',
#     'title': 'Raleigh Banana',
#     'linked': False},
#    {'uid': '870383398ea18eaf4eaacf6df97486f8',
#     'artist': 'Town Centre',
#     'title': "Maybe I'm Alone",
#     'linked': False},
#    {'uid': '2a2c8b5173b13e31b9e86f61eda8d7fc',
#     'artist': 'DJ Scriby',
#     'title': 'Glom Couture',
#     'linked': False},
#    {'uid': 'b09a2c8197358e8758a6d33466947181',
#     'artist': 'MC Caue',
#     'title': 'Bate Tambor (DJ Beukeboom Edit)',
#     'linked': False},
#    {'uid': '4073b454f91fab50a70886cbfd747cb8',
#     'artist': 'Rezzett',
#     'title': 'Leg It',
#     'linked': True},
#    {'uid': 'fc4c8662990a3803d85c2747d7dff95b',
#     'artist': 'Brunnera',
#     'title': 'Nox Rain',
#     'linked': False},
#    {'uid': '63092316a89be5b96ba10a2b00700c75',
#     'artist': 'Yungdb',
#     'title': 'Lets Go Out',
#     'linked': False},
#    {'uid': '1cca6d315867d27b94b02e29a0e85c38',
#     'artist': 'Wobbly feat. Ana Machado',
#     'title': 'White Eggs (with Ana Machado)',
#     'linked': False},
#    {'uid': 'de3dbe64721d971228886b2c4e9f4964',
#     'artist': 'Nocera',
#     'title': 'Summertime, Summertime (Hard Summer Dub)',
#     'linked': True},
#    {'uid': 'ca3e15a02e5fc5fdf01164af6b94c56c',
#     'artist': 'Amarú',
#     'title': 'Fe En La Mantis (Estoc Remix)',
#     'linked': False}]},
#  'high-hopes-w-judah-16th-july-2023': {'url': '/shows/high-hopes-w-judah/episodes/high-hopes-w-judah-16th-july-2023',
#   'name': 'High Hopes w/ Judah',
#   'loc': None,
#   'date': '16.07.23',
#   'tracks': [{'uid': '6e49d8d312bd6db8eec5f6f665f88afc',
#     'artist': 'Okonski',
#     'title': 'Sunday',
#     'linked': False},
#    {'uid': 'b0db1537fd3f8fa733fa7c2bb53219a3',
#     'artist': 'Wayne Shorter',
#     'title': 'Ponte De Areia',
#     'linked': True},
#    {'uid': 'f1e594b3c09f1c250b992b9055ea6f1e',
#     'artist': 'Noel Mc Ghie & Space Spies',
#     'title': 'Trapeze',
#     'linked': True},
#    {'uid': 'e8a93e1fc68ccb40e6b58f9ccc9991a5',
#     'artist': 'Van Morrison',
#     'title': 'Wild Honey',
#     'linked': False},
#    {'uid': '2c96bf03d32b1b46a4366170b4146b0b',
#     'artist': 'Curtis Mayfield',
#     'title': 'Never Stop Loving Me',
#     'linked': True},
#    {'uid': 'cb2c94f89b306cc03e19025e60216c66',
#     'artist': 'Ziyad Al Rahbani',
#     'title': 'Houdou Nisbi',
#     'linked': False},
#    {'uid': '4b81e6a99ac1360983462fe03a03187f',
#     'artist': 'Lonnie Liston Smith & The Cosmic Echoes',
#     'title': 'Sais (Egypt)',
#     'linked': True},
#    {'uid': '6f836bb7c4d7c38a175a5f84037a74c3',
#     'artist': 'Antoinette Konan',
#     'title': 'M’ack',
#     'linked': False},
#    {'uid': '43cedda7cf228da86f53907418ce0d46',
#     'artist': 'A.B. Crentsil',
#     'title': 'Obi Baa Wiase',
#     'linked': True},
#    {'uid': '0f4ef8706d3785a5ed74ec45701654ac',
#     'artist': 'Jonny Nash, Suzanne Kraft',
#     'title': 'Refractory Cafe',
#     'linked': True},
#    {'uid': 'f747ed8bb2f263fce120054ac2bfdb25',
#     'artist': 'Erykah Badu',
#     'title': 'Incense (Feat. Kirsten Agresta)',
#     'linked': False}]},
#  'jana-rush-15th-july-2023': {'url': '/shows/jana-rush/episodes/jana-rush-15th-july-2023',
#   'name': 'Composuresquad ',
#   'loc': 'Chicago',
#   'date': '15.07.23',
#   'tracks': [{'uid': '74c93e314c8aadc6113c210a949f29b5',
#     'artist': 'Fred Hammond & Radical For Christ',
#     'title': 'I Wanna Know Your Ways',
#     'linked': False},
#    {'uid': 'ed29ee4c66f97daaa46435a8816ecca3',
#     'artist': 'Yeat',
#     'title': 'Nun I’d Change',
#     'linked': False},
#    {'uid': 'fa5e11eb7063bf83ee99c49ac97735c1',
#     'artist': 'Bok Bok',
#     'title': 'Duetto',
#     'linked': True},
#    {'uid': 'a1820d52685a1c0a25300e6d61cdb072',
#     'artist': 'Public Appeal',
#     'title': 'So Bad (Explicit)',
#     'linked': False},
#    {'uid': 'c65aebb79adf6f2668a3a982bbda0696',
#     'artist': 'Lil Loaded',
#     'title': '6locc 6a6y Ways',
#     'linked': True},
#    {'uid': '76224ac8c7cae732bb4876aa5b9bdfec',
#     'artist': 'Composuresquad',
#     'title': 'Its All Relative To Feature Me (Flo X Cando)',
#     'linked': False},
#    {'uid': '52276e7aa668ff11fc8874f6e34589f4',
#     'artist': 'Club Eat',
#     'title': 'No Sex',
#     'linked': True},
#    {'uid': '0a3ffefdf4ac16bcfcdc0e449bd18b0c',
#     'artist': 'Composuresquad',
#     'title': 'Sideways',
#     'linked': False},
#    {'uid': '8b3808e60f9bcd926d51b92d567e734a',
#     'artist': 'Composuresquad',
#     'title': 'worms wiggle',
#     'linked': False},
#    {'uid': '433126d03e6e73c98b3e1fc3382dbdfb',
#     'artist': 'Composuresquad',
#     'title': 'Drum Track (With Jace Inman)',
#     'linked': False},
#    {'uid': '24122c248e2597cae4c9cdb5ef180767',
#     'artist': 'Coco Bryce',
#     'title': 'Canaan',
#     'linked': False},
#    {'uid': '1c95a72f00f2c7d0267c86f57fc79923',
#     'artist': 'Mincy',
#     'title': 'Mutant Flowers',
#     'linked': False},
#    {'uid': '6b0fbf08356f1cea982dbd35fef7303d',
#     'artist': 'Composuresquad',
#     'title': 'Fated To Break (With Please)',
#     'linked': False},
#    {'uid': 'fd96ea5fc0f65eca9ff277dbeddce931',
#     'artist': 'Nguzunguzu',
#     'title': 'Drop Cage',
#     'linked': True},
#    {'uid': 'c93f78c1f538f2af37e4fbce81515a9e',
#     'artist': 'Ariel Zetina',
#     'title': 'Water Nymph',
#     'linked': True},
#    {'uid': '8e427c3e75828814920c4bd6e974dbd5',
#     'artist': 'K.Oz',
#     'title': 'Anna',
#     'linked': False},
#    {'uid': 'c944776b1fb66025ff4fa4853721f557',
#     'artist': 'Normal Nada The Krakmaxter',
#     'title': 'Batida 8',
#     'linked': False},
#    {'uid': '859dad3e75b10af6e3b0dc6b6f5d2a05',
#     'artist': 'Alien D',
#     'title': 'Party Glitters',
#     'linked': False},
#    {'uid': '860927829df82fce823d7ff80c6f4406',
#     'artist': 'Miss Twink USA',
#     'title': 'Got Me All Excited',
#     'linked': False},
#    {'uid': 'a1f2037479a458a625f2f7783d02ffe5',
#     'artist': 'Nahash',
#     'title': 'Illuminato',
#     'linked': True},
#    {'uid': '221da9d1d3309a2ca8e0ff3585854ea3',
#     'artist': 'Chemist',
#     'title': 'From Ashes',
#     'linked': False},
#    {'uid': '52133a64bb3d35418ce0790e594543e8',
#     'artist': 'Rp Boo',
#     'title': 'Azz Out Of Control',
#     'linked': False},
#    {'uid': '1b0d8fd76fd823cf0209f9c68eebb091',
#     'artist': 'Composuresquad',
#     'title': 'Shygirl X Kush Jones Supah Coochie(A Jacktime Story)',
#     'linked': False},
#    {'uid': 'd310db3500af26aba54d498d8e3c1855',
#     'artist': 'Erika de Casier',
#     'title': 'What u Wanna Do?',
#     'linked': True},
#    {'uid': '4ea434a87c387bd4ce2996cbf23ff197',
#     'artist': 'Composuresquad',
#     'title': 'Namio H',
#     'linked': False},
#    {'uid': '85b8168c5792f61b2ade77ae44f01402',
#     'artist': 'Composuresquad',
#     'title': 'Florence B. Price In The Chamber',
#     'linked': False}]},
#  'soundsofthedawn-15th-july-2023': {'url': '/shows/soundsofthedawn/episodes/soundsofthedawn-15th-july-2023',
#   'name': 'Sounds Of The Dawn',
#   'loc': 'Detroit',
#   'date': '15.07.23',
#   'tracks': [{'uid': '503cf9b689f7f4715473446bd2ad7bfa',
#     'artist': 'Nanak Dev Singh Khalsa',
#     'title': 'Sound Of The Gong',
#     'linked': False},
#    {'uid': '0211cc58bf47d474e7d4e2901e84da1f',
#     'artist': 'Stephen Winfield, Kat West',
#     'title': 'Secrets Never Told',
#     'linked': False},
#    {'uid': '61d43f9793b3db0bcb5ab0844789529c',
#     'artist': 'Frank Lorentzen',
#     'title': 'Hands',
#     'linked': False},
#    {'uid': '7e6d4b1f03fc6931d215d7fedecf9844',
#     'artist': 'Deuter',
#     'title': 'Land Of Enchantment',
#     'linked': False},
#    {'uid': 'd5ac2ca7151dbf1822af799ff241c7fe',
#     'artist': 'Jabrane M. Sebnat',
#     'title': 'Alif-Ya',
#     'linked': False},
#    {'uid': '9ad97b71547d8a1ded7cda8e2c360662',
#     'artist': 'Paul A. Sutin',
#     'title': 'Deep Serenity',
#     'linked': False},
#    {'uid': '944f90b0f9a58ee674a53a7daefa4cf3',
#     'artist': 'Dick Tilton',
#     'title': 'Searcher',
#     'linked': False},
#    {'uid': '3f705e911cc41f91a809a64eadd19e38',
#     'artist': 'Denis Quinn',
#     'title': 'Open Secret',
#     'linked': False},
#    {'uid': '8c1ce15313860be1f15bb05563144548',
#     'artist': 'Karma Moffett',
#     'title': 'Chomolhari',
#     'linked': False},
#    {'uid': '684f7245bd5ddd7d2f4f9351165e3855',
#     'artist': 'Spirit Liberation Ensemble',
#     'title': 'Dākinī Dreams',
#     'linked': False}]},
#  'the-nts-guide-to-canadian-new-age-15th-july-2023': {'url': '/shows/the-nts-guide-to/episodes/the-nts-guide-to-canadian-new-age-15th-july-2023',
#   'name': 'NTS Guide to: Canadian New Age 1980-87',
#   'loc': 'London',
#   'date': '15.07.23',
#   'tracks': [{'uid': 'e18efe4a62e2135a29458108cca290a2',
#     'artist': 'Shyam',
#     'title': 'I Deal With Silence',
#     'linked': True},
#    {'uid': '8d74a791763b8065cf099c13f9108c40',
#     'artist': 'D. A. Dettmar',
#     'title': 'Pacific Rain Forest',
#     'linked': False},
#    {'uid': 'e6f623e39ab42f24a2a875bf87e9e0e3',
#     'artist': 'Chris Wind',
#     'title': 'Fernmist',
#     'linked': False},
#    {'uid': '7355fce9ed56688390fb9e3190be3dea',
#     'artist': "J.P. L'Heureux, M. Laperle",
#     'title': 'Au Clair De Lune',
#     'linked': False},
#    {'uid': '66e9bc3cd8c5229be6cb13dffe56b690',
#     'artist': 'Letter Tree',
#     'title': "Village Planétaire - Energy Path = Sentier De L'énergie",
#     'linked': False},
#    {'uid': '760d9f73bf7a18a51fed51b8fd206ab5',
#     'artist': 'Beverly Glenn-Copeland',
#     'title': 'Old Melody',
#     'linked': True},
#    {'uid': '8b01c5b05db52a1c01e68ce6b60da1ed',
#     'artist': 'Alithia Hambleton',
#     'title': 'Akasha',
#     'linked': False},
#    {'uid': '68fdb247f61460bae6cfff0d5d106ed6',
#     'artist': 'Brent Snyder',
#     'title': 'Excursion',
#     'linked': False},
#    {'uid': '4a5d2aa57c70d6c36ab8f006b4aa40a0',
#     'artist': 'Jean-Pierre Labrèche',
#     'title': 'Ode Au Lever Du Soleil',
#     'linked': False},
#    {'uid': '052c5f65383d74da050d777aa4a664a4',
#     'artist': 'Alex Jones, Douglas Cutler',
#     'title': 'Inside The Hollow',
#     'linked': False},
#    {'uid': '766e95fe1102580c411c9becfd4ae857',
#     'artist': 'Grant MacKay',
#     'title': 'Echo Shadows',
#     'linked': False},
#    {'uid': 'c3de906ac3b781995add052657a7bca5',
#     'artist': 'Mychael Danna & Tim Clément',
#     'title': 'Ontario',
#     'linked': False}]},
#  'bergsonist-15th-july-2023': {'url': '/shows/bergsonist/episodes/bergsonist-15th-july-2023',
#   'name': 'Bergsonist',
#   'loc': 'New York',
#   'date': '15.07.23',
#   'tracks': [{'uid': '5e9f1f317a59041b477f7caef67ff224',
#     'artist': 'Bergsonist',
#     'title': 'Dopplerwater',
#     'linked': False},
#    {'uid': '3a6b9a7adbbe98e1225e2c271837a0cb',
#     'artist': 'Newcleus',
#     'title': 'Automan (Dub Version)',
#     'linked': True},
#    {'uid': '1c97a375a2fc6cb485318954867451cf',
#     'artist': 'Bergsonist',
#     'title': 'Synaptic Dimension',
#     'linked': False},
#    {'uid': 'c77273aeaaeab576fe1d3ca27c5bc24a',
#     'artist': 'Delroy Edwards',
#     'title': 'Now U In My Trunk',
#     'linked': True},
#    {'uid': 'c377a29aedc5acf75232c63031a0b7a6',
#     'artist': 'Claude Young (Remix by Ican)',
#     'title': 'Impolite To Refuse (ICAN Remake)',
#     'linked': True},
#    {'uid': 'd8d8b6853658cc04f38105bb918765c8',
#     'artist': 'Oneiric',
#     'title': 'Blue Envelope',
#     'linked': False},
#    {'uid': 'd9ccd07a9bec90eed5bcde2b84a795d3',
#     'artist': 'not even noticed',
#     'title': 'Electromagnetic Field',
#     'linked': False},
#    {'uid': '6a5db073d49790b89823b60e8931eb05',
#     'artist': 'G.Zifcak',
#     'title': 'Trudge The Peaks & Troughs Of Happy Diodes',
#     'linked': False},
#    {'uid': '32ea67ea34a4c36b442b62f7658b9163',
#     'artist': 'Bergsonist',
#     'title': 'Conditional',
#     'linked': False},
#    {'uid': '789feb638eb299f767dfadfbf0d13d37',
#     'artist': 'Transparent Sound',
#     'title': 'Remanisance',
#     'linked': True},
#    {'uid': 'c0aa5613786c3c1d064321d797dbab33',
#     'artist': 'Dataintrång / Luke Eargoggle',
#     'title': 'Kodak Moment (Ft. Br.Beta)',
#     'linked': False},
#    {'uid': '620d75dc1e163bf8d5e3c20298ac487b',
#     'artist': 'Code 3',
#     'title': 'Code-Of-Acid (Club Mix)',
#     'linked': False},
#    {'uid': '3b2c5ba0cf7bfec2b16c09144d6d50de',
#     'artist': 'Kenneth X',
#     'title': 'HewManKonTakt',
#     'linked': False},
#    {'uid': '9b1c50e65244be03dca37d99c328dabc',
#     'artist': 'G.Zifcak',
#     'title': 'Ducky Dirter',
#     'linked': False},
#    {'uid': 'b75a15475f95ee54e1edc73f7e687f86',
#     'artist': 'Das Muster',
#     'title': 'Visionbaby',
#     'linked': False},
#    {'uid': '754eda116abd1834febdc2ff31df2029',
#     'artist': 'Juzer',
#     'title': 'Ribtickler',
#     'linked': False},
#    {'uid': '593eb104a633ac8db9685c855b27665d',
#     'artist': 'DJ Spider',
#     'title': 'Mind Field',
#     'linked': False},
#    {'uid': '8f0d2a2940539f9068624155a4589033',
#     'artist': 'Enrico Mantini, X Woman',
#     'title': 'What U Want (The Original)',
#     'linked': False},
#    {'uid': 'cbbea6b9d1f39e3556d84af35a5465ff',
#     'artist': 'Dataintrång / Luke Eargoggle',
#     'title': 'Synthesized Safari',
#     'linked': False},
#    {'uid': 'd44bf89111c913404913039539f6d01e',
#     'artist': 'Toshiya Tsunoda',
#     'title': 'Landscape And Voice',
#     'linked': False},
#    {'uid': 'f61dde31368349e73a6e35c5d562dc19',
#     'artist': 'Bergsonist',
#     'title': 'Escher Dreamlike',
#     'linked': False},
#    {'uid': '13e3a51e125eb52a20efcce574127fa3',
#     'artist': 'Iannis Xenakis',
#     'title': 'Concret Ph',
#     'linked': True},
#    {'uid': 'e7932c7094da223a160634f302a564fa',
#     'artist': 'Étant Donnés',
#     'title': '8:26',
#     'linked': False}]},
#  'felisha-ledesma-15th-july-2023': {'url': '/shows/felisha-ledesma/episodes/felisha-ledesma-15th-july-2023',
#   'name': 'Felisha Ledesma w/ Dania',
#   'loc': 'Malmö',
#   'date': '15.07.23',
#   'tracks': [{'uid': '6e8e29c19a49a05c6e37a1641ac9131c',
#     'artist': 'Lamin Fofana',
#     'title': 'Here Lies Universality',
#     'linked': True},
#    {'uid': 'cfe9ab88804cffb6d03628eb6ea1404a',
#     'artist': 'Dania & Rupert Clervaux',
#     'title': 'Acción Y Destino',
#     'linked': False},
#    {'uid': 'e9aa649c2988019c04c8e6123c7fd4d5',
#     'artist': 'Chantal Michelle',
#     'title': 'Blue In Blue',
#     'linked': True},
#    {'uid': '3c091dd64585d7244317641b46599c7e',
#     'artist': 'Theodore Cale Schafer',
#     'title': 'Mansfield',
#     'linked': True},
#    {'uid': 'b9a201ccb01dd619a4a4275930b3f085',
#     'artist': 'Cole Pulice',
#     'title': 'If I Don’t See You In The Future, I’ll See You In The Pasture',
#     'linked': False},
#    {'uid': '95b9ef5d2c7d3692df887dce6400bc91',
#     'artist': 'Ylia',
#     'title': 'Todos los Cuerpos',
#     'linked': False},
#    {'uid': 'a31c52e130258556e9120957d4d00357',
#     'artist': 'Rosso Polare',
#     'title': 'albanella',
#     'linked': True},
#    {'uid': '69e02650658286249e937adbc5d981dc',
#     'artist': 'Joy Helder',
#     'title': 'Ooooooooo',
#     'linked': False},
#    {'uid': '1f1322296edab1582197b3fce865ad97',
#     'artist': 'Teresa Winter',
#     'title': 'How Strange Are Bodies?',
#     'linked': False},
#    {'uid': 'e35be0b2813d9bbca3fb684a434f6b1e',
#     'artist': 'Not Waving',
#     'title': 'I Found You',
#     'linked': False},
#    {'uid': '47cc27baf5db3d72db0dbefb01705632',
#     'artist': 'Qow',
#     'title': 'Kol Maghanni Ft. Marianna Jouzova',
#     'linked': False},
#    {'uid': '8681aebc42a74d666fccb0125baa60b6',
#     'artist': 'Yatta',
#     'title': 'Fully Lost, Fully Found',
#     'linked': True},
#    {'uid': 'de1eb2944f32ffef2315b4188ecb242c',
#     'artist': 'Selvhenter',
#     'title': 'Sub Lunar',
#     'linked': False},
#    {'uid': '58a32e291a6142bb90a033ed63bb6f9a',
#     'artist': 'Jake Muir',
#     'title': 'Unreleased',
#     'linked': False}]},
#  'ernesto-chahoud-15th-july-2023': {'url': '/shows/ernesto-chahoud/episodes/ernesto-chahoud-15th-july-2023',
#   'name': 'Beirut Daze w/ Ernesto Chahoud & Fergus Richardson',
#   'loc': 'Beirut',
#   'date': '15.07.23',
#   'tracks': [{'uid': '94efc3c397e5d9212f681c5b5b0adfa5',
#     'artist': 'Witch',
#     'title': 'You Are My Sunshine ',
#     'linked': True},
#    {'uid': 'd5ba5796bc7e67faac54232530a198c9',
#     'artist': 'Golden Hands',
#     'title': 'Take Me Back',
#     'linked': True},
#    {'uid': '0fd30bd5e4dee2f2c610d8b5df4b1be6',
#     'artist': 'Shams Dinn',
#     'title': 'Hedi Blad Noum (Instrumental)',
#     'linked': False},
#    {'uid': 'f1e7eae6b46ef5fda7718f526d7935f6',
#     'artist': 'Fadela',
#     'title': "N'Sel Fik",
#     'linked': True},
#    {'uid': '395253e006412f988019f52d4dfadef1',
#     'artist': 'Chab Sherquai',
#     'title': 'Hana Hana',
#     'linked': False},
#    {'uid': '365ab267208ef4d19c4768edbdd86d20',
#     'artist': 'Mohammed El Abd',
#     'title': 'Ya Sari',
#     'linked': False},
#    {'uid': '07cfb1fb7b7b97f5e7c5af113e21e356',
#     'artist': 'Azar Habib',
#     'title': 'Lawlaki Ya Malaki',
#     'linked': False},
#    {'uid': '5bcbeb44aa65812c92a3b4b2eeb1d39e',
#     'artist': 'Sammy Clark',
#     'title': "Oumi Tanor'ss",
#     'linked': False},
#    {'uid': 'cbf03bdb5b1ae326578bcaacb97fd075',
#     'artist': 'Robert Maalouf',
#     'title': 'Ana W Leil',
#     'linked': False},
#    {'uid': '94847b65375f5c49e28fbee9d6c447ba',
#     'artist': 'Amar Sharii',
#     'title': 'Asmar Ya Asmarani',
#     'linked': False},
#    {'uid': '7ff5711bbee21d894522bc927be98b08',
#     'artist': 'Joseph Nassif',
#     'title': 'Btizkor Min Zaman',
#     'linked': False},
#    {'uid': 'db7617e017ae7fd55b040acee9cfe92f',
#     'artist': 'Elias Rahbani',
#     'title': "Lover's Lane",
#     'linked': False},
#    {'uid': 'a6566acca7976c39c1f9c92fbf8a746e',
#     'artist': 'Robert Chamma',
#     'title': "Ba'ref Inek Bithini",
#     'linked': False},
#    {'uid': 'b44320974236c2901893de2ad3747d59',
#     'artist': 'Omar Khorshid',
#     'title': "Raksat Al Fada'",
#     'linked': False},
#    {'uid': '3af62f16e365da0a550550c94157b470',
#     'artist': 'Ihsan Al-Munzer',
#     'title': 'Dindolo',
#     'linked': False},
#    {'uid': 'af635064d262d6f51d94dcc51e0f6cd9',
#     'artist': 'زياد الرحباني',
#     'title': 'Prelude',
#     'linked': False},
#    {'uid': 'd748324d22637d8a98728d98628634b1',
#     'artist': 'وليد غلمية, Walid Gholmieh',
#     'title': 'Amaris',
#     'linked': False},
#    {'uid': '69e06a8e37575d27752da892e74713a1',
#     'artist': 'Mona Merashli',
#     'title': 'Salem Ya Hamam',
#     'linked': False}]},
#  'last-resort-15th-july-2023': {'url': '/shows/last-resort/episodes/last-resort-15th-july-2023',
#   'name': 'Last Resort w/ G.S. Schray',
#   'loc': 'London',
#   'date': '15.07.23',
#   'tracks': [{'uid': '40d1cc83432c2b988c3a7cb68c3b3a24',
#     'artist': 'Another Channel feat. Babe Roots',
#     'title': 'Money Run Things',
#     'linked': False},
#    {'uid': 'ed88d5adc058504e216bf9ed2fe28ccc',
#     'artist': 'Rhythm & Sound, Tikiman',
#     'title': 'Never Tell You',
#     'linked': False},
#    {'uid': '420768897c5146f4efd275056c819ca4',
#     'artist': 'Zion Train, The Tassilli Players',
#     'title': 'Sensi',
#     'linked': False},
#    {'uid': 'e5d0a455a6eab95049f7c70768edb4b3',
#     'artist': 'Pampidoo (Remix by Legowelt)',
#     'title': 'Synthesizer Voice (Legowelt Remix)',
#     'linked': True},
#    {'uid': 'e55f60819e192003430fc15ed9178b5c',
#     'artist': 'CS + Kreme',
#     'title': 'Bassline',
#     'linked': True},
#    {'uid': '5918aeff52a3e895f0031b22c9558489',
#     'artist': 'BARRY WALKER JR.',
#     'title': 'Sweet Spectral Iapetus',
#     'linked': False},
#    {'uid': 'ab2442999d30edb230069fe51b4d9103',
#     'artist': 'Branko Mataja',
#     'title': 'Tamo Daleko / Far Away',
#     'linked': True},
#    {'uid': '3310fae8c2d6d96e809e5203e6a10316',
#     'artist': 'Nabihah Iqbal',
#     'title': 'Eden Piece',
#     'linked': True},
#    {'uid': 'aba02ac9af98e39079ef97adca49fe49',
#     'artist': 'Froid Dub',
#     'title': 'Wet Dub',
#     'linked': True},
#    {'uid': 'a7de574daa60e6208fc78c618ad440fa',
#     'artist': 'Theodore Cale Schafer',
#     'title': 'See You Soon',
#     'linked': True},
#    {'uid': '97f62db5875cc9246602f1fb307b27b9',
#     'artist': 'JULIA PERRY',
#     'title': 'Homunculus, C.F. (Excerpt)',
#     'linked': False},
#    {'uid': 'e56ebced3870a4d0cb027b296f32597f',
#     'artist': 'I.K.G.',
#     'title': 'Unfinished #5',
#     'linked': False}]},
#  'labour-15th-july-2023': {'url': '/shows/labour/episodes/labour-15th-july-2023',
#   'name': 'LABOUR w/ Aby Ndour',
#   'loc': 'DAKAR',
#   'date': '15.07.23',
#   'tracks': [{'uid': 'f0ce7bac87c9258f24f9aa94d708b160',
#     'artist': 'Maty Thiam Dogo',
#     'title': 'Talibé (Général Kara)',
#     'linked': True},
#    {'uid': 'd6d1872ee74a54eed519da46e49b2633',
#     'artist': 'Maty Thiam Dogo',
#     'title': 'Ku Sumb Tooy',
#     'linked': False},
#    {'uid': '091d1536f034560d59fd0f04612ec9ac',
#     'artist': 'Maty Thiam Dogo',
#     'title': 'Tukki Aayul',
#     'linked': False},
#    {'uid': '11ec6ed3724cfc2bdb2cdc4a8129648a',
#     'artist': 'Maty Thiam Dogo',
#     'title': 'Doom-Ja Ndey-Ja',
#     'linked': False},
#    {'uid': '4aabec3d1cedb954314bf818ebccaed4',
#     'artist': 'Maty Thiam Dogo',
#     'title': 'Fataliku',
#     'linked': False},
#    {'uid': '39193c13a1cec69ef00db1d60eb60781',
#     'artist': 'Soda Mama Fall',
#     'title': 'Serigne Mb. S. Lô',
#     'linked': False},
#    {'uid': '31e46442f9318d2926ce9f00dcc92fac',
#     'artist': 'Soda Mama Fall',
#     'title': 'Darou Salam',
#     'linked': False},
#    {'uid': '8259320b44880306010c176eace9e38f',
#     'artist': 'Maty Thiam Dogo',
#     'title': 'Yoonu Ndaw Du Gaaw',
#     'linked': False},
#    {'uid': 'bbd41007cb5c6dd873b8b455f0661266',
#     'artist': 'Maty Thiam Dogo',
#     'title': 'Yaraam Cheikh',
#     'linked': False},
#    {'uid': 'e1b11c3169f9533ad33a50f779a75fb9',
#     'artist': 'Maty Thiam Dogo',
#     'title': 'Gora Jara Àndal',
#     'linked': False},
#    {'uid': '81f393a20378f24661f23226740fe019',
#     'artist': 'Aida Samb Ft. Mbaye Dieye Faye',
#     'title': 'Daling Kor',
#     'linked': False},
#    {'uid': '693da4d2e7cc86a02f91c256973d9b2a',
#     'artist': 'Wally B. Seck',
#     'title': 'Waka Waka',
#     'linked': False}]},
#  'tom-boogizm-15th-july-2023': {'url': '/shows/tom-boogizm/episodes/tom-boogizm-15th-july-2023',
#   'name': "Robbin' Lobsters From Mobsters w/ Tom Boogizm",
#   'loc': 'Manchester',
#   'date': '15.07.23',
#   'tracks': [{'uid': 'e261911b5b7688f4cf6c3f71f7efaca2',
#     'artist': 'Yardtech',
#     'title': 'Untitled',
#     'linked': True},
#    {'uid': '4e819c8846ee5a3f2a0bce86bb449e4f',
#     'artist': 'Klein',
#     'title': 'Changes',
#     'linked': True},
#    {'uid': 'e68a62db1b512a02211f7d71eeabeb76',
#     'artist': 'Equiknoxx',
#     'title': 'Clunk',
#     'linked': False},
#    {'uid': 'cbe5da1fcaf41d63e11f3f7c62ce8b75',
#     'artist': 'Matias Aguayo & The Desdemonas',
#     'title': 'After Love',
#     'linked': False},
#    {'uid': '13e62b76a1a537818d6265d4a212ef60',
#     'artist': 'Hardijs Lediņš',
#     'title': 'Lambs',
#     'linked': False},
#    {'uid': '4f09924b0992160cb2eb2fc6e3d2d7e3',
#     'artist': 'Van Kaye + Ignit',
#     'title': 'Chapel',
#     'linked': False},
#    {'uid': '6255b3c4619a1e2efe2a9e7a746100cd',
#     'artist': 'Michael J. Blood, Rat Heart (MCR), Sockethead',
#     'title': 'Untitled',
#     'linked': False},
#    {'uid': '3916851cdb2e1fee10caf8a3ec3ba022',
#     'artist': 'VHOOR',
#     'title': '1Dez',
#     'linked': True},
#    {'uid': 'a1b0b0393da07e27c54231f1d862f722',
#     'artist': 'Kini 1 Kini',
#     'title': 'Boko Zika',
#     'linked': False},
#    {'uid': '9581479463faed4116355b3d7def8ff9',
#     'artist': 'NPK',
#     'title': 'Violent Addicts (Feat. Tugga & Shemz)',
#     'linked': False},
#    {'uid': 'b09289ae87099de435912dd72c0d2445',
#     'artist': 'A.I.M',
#     'title': 'White Cocaine (feat. Benji Smalls)',
#     'linked': False},
#    {'uid': 'bf6d2f542b6f2eea9447e3be1a05894f',
#     'artist': 'Authentically Plastic',
#     'title': 'Aesthetic Terrorism',
#     'linked': True},
#    {'uid': '9efb86ca022de3a9ece4bc3d0e7e14ba',
#     'artist': 'Ikonika',
#     'title': 'What Kinda Pain Are We Talking About',
#     'linked': True},
#    {'uid': '699102fa2eb884bebccf37ee174ae223',
#     'artist': 'VHOOR',
#     'title': 'Primavera',
#     'linked': True},
#    {'uid': '303a2cfa0bc6094a321ac3fd83d24255',
#     'artist': 'Culoe De Song',
#     'title': 'Sacred Dance',
#     'linked': False},
#    {'uid': '6b17d0b187a70dcb99a4176179289044',
#     'artist': 'Bekzin Terris',
#     'title': 'King Solomon',
#     'linked': False},
#    {'uid': '5c563954175cbb20d3f2adce8f279c01',
#     'artist': 'DJ Spoko feat. Kapa Kapa',
#     'title': 'Batauweng',
#     'linked': False},
#    {'uid': '60467ed7aef78b3e133b2e1208c1eda4',
#     'artist': 'DJ Toxic, Cue & Merg',
#     'title': 'Son Of Dragon',
#     'linked': False},
#    {'uid': '27f9813e320a8dc05fae7595db2d5e9b',
#     'artist': 'Karizma',
#     'title': 'Twyst This',
#     'linked': True}]},
#  'the-bennett-show-14th-july-2023': {'url': '/shows/the-bennett-show/episodes/the-bennett-show-14th-july-2023',
#   'name': 'The Bennett Show',
#   'loc': 'Los Angeles',
#   'date': '14.07.23',
#   'tracks': [{'uid': '0e0ac093f3f370af457d9e54e0ef4d75',
#     'artist': 'Rikk Agnew',
#     'title': 'Section 8',
#     'linked': False},
#    {'uid': '996605c6a82c86442682ddc762737763',
#     'artist': 'Scott Williams',
#     'title': 'He Is Gone',
#     'linked': False},
#    {'uid': 'df6af6567d2b4dbdd522a8fd82dc78e4',
#     'artist': 'Vox Pop',
#     'title': 'Production',
#     'linked': False},
#    {'uid': 'cf3b2753c6e70e4648b77f4127e0bbfe',
#     'artist': 'The Germs',
#     'title': 'No God',
#     'linked': False},
#    {'uid': '9c8869d6ac7ff018aed21308dc7e7548',
#     'artist': 'Moss Icon',
#     'title': 'Divinity Cove',
#     'linked': False},
#    {'uid': 'b11142390f28af38f92b0d973a8db930',
#     'artist': 'Sweet Smoke',
#     'title': 'Mary Jane Is To Love',
#     'linked': False},
#    {'uid': '4f9c49ce5570c02409da732f0d175ae4',
#     'artist': 'Mutabaruka',
#     'title': 'Whiteman Country',
#     'linked': True},
#    {'uid': '5d54f3821194408c7ad253b725f4e4b3',
#     'artist': 'Plus Instruments',
#     'title': 'Things',
#     'linked': True},
#    {'uid': '6b646ee77951de611ce4a3c0b5e0f9b0',
#     'artist': 'No More',
#     'title': 'Suicide Commando',
#     'linked': True},
#    {'uid': '4b8899f92b8beba43e62c705c0bdbc2d',
#     'artist': 'The Stranglers',
#     'title': 'Straighten Out',
#     'linked': False},
#    {'uid': '45dbad96bf20b373a8728154a6506da5',
#     'artist': 'APB',
#     'title': 'Talk To Me',
#     'linked': False},
#    {'uid': '9373aca0320f1a31e68e712096c392e6',
#     'artist': 'Gun Club',
#     'title': 'Sleep Time Blues [Nobody’s City]',
#     'linked': False},
#    {'uid': '77b69b4ec603cf0d1b02bc7bebd94687',
#     'artist': 'Sun City Girls',
#     'title': 'The Shining Path',
#     'linked': True},
#    {'uid': 'cedeb964dd62c6e726778b7e533cc2b3',
#     'artist': 'Secos & Molhados',
#     'title': 'Flores Astrais',
#     'linked': True},
#    {'uid': '21d64b4145ceb4098f73ea4895bfef0d',
#     'artist': 'Omega Tribe',
#     'title': 'Picture Now',
#     'linked': False},
#    {'uid': '1f47858a6262cfc9fc04c80dc59a94f0',
#     'artist': 'R. Dean Taylor',
#     'title': 'Indiana Wants Me',
#     'linked': False},
#    {'uid': '13e28a0ba3d4f8348a8f53a3f3486ab8',
#     'artist': 'The Flesh Eaters',
#     'title': 'Police Gun Jitters',
#     'linked': False},
#    {'uid': '94d9e599fa75b6c5a3139631e3c17d2c',
#     'artist': 'Devo',
#     'title': 'The Day My Baby Gave Me A Surprize',
#     'linked': False},
#    {'uid': '68d382dea33ce9f7ff020223eaaacf4f',
#     'artist': 'Syrinx',
#     'title': 'Hollywood Dream Trip',
#     'linked': True},
#    {'uid': 'bd274b8bc28f7bc39b058873ade619b3',
#     'artist': 'The Inner Space',
#     'title': 'Kamerasong',
#     'linked': False},
#    {'uid': '8a49b6947dbb1a4a8adc1bb74f22dc12',
#     'artist': 'Bad Brains',
#     'title': 'Don’t Bother Me',
#     'linked': True},
#    {'uid': '6eab634d950a3884bd449cca5677fd21',
#     'artist': 'Wipers',
#     'title': 'Romeo',
#     'linked': False},
#    {'uid': 'c16d75f99151e8f2be2f330c6ee8601d',
#     'artist': 'The Selecter',
#     'title': 'The Selecter',
#     'linked': True},
#    {'uid': '43c210fd40bccc56401ee7affb2a3340',
#     'artist': 'Horse Mouth',
#     'title': 'Herb Vendor',
#     'linked': True},
#    {'uid': 'b76070929636c532b943ada03c68e16e',
#     'artist': 'Mirage',
#     'title': 'Ebaneezer Beaver',
#     'linked': False},
#    {'uid': 'f2651ee5ef6ac2bc7cbc17a29c571236',
#     'artist': 'Reagan Youth',
#     'title': 'Back To The Garden (Parts I-IV)',
#     'linked': False},
#    {'uid': 'd4bd8624838387d852e4a7cca0fddcbc',
#     'artist': 'Scream',
#     'title': 'Walking Song Dub',
#     'linked': False},
#    {'uid': '54743a1ef1db5fa0168f0faaeac89846',
#     'artist': 'Klan',
#     'title': "Pushin' Too Hard",
#     'linked': False},
#    {'uid': '0c290a51a5a71d76ce7e6cfb1aa10879',
#     'artist': 'Panic',
#     'title': 'S.For Dic.',
#     'linked': False},
#    {'uid': '5f1c1f4555b8e21c350ac3b5628b556b',
#     'artist': 'The Association',
#     'title': 'The Time It Is Today',
#     'linked': True},
#    {'uid': 'ce52abf1c5fc775cddb97595f646dc3b',
#     'artist': 'The Kinks',
#     'title': 'Where Have All The Good Times Gone',
#     'linked': True},
#    {'uid': '818157efa6ad419f4b92562319e9c031',
#     'artist': 'Agincourt',
#     'title': 'All My Life',
#     'linked': True},
#    {'uid': '5a0c72d34aedbf3b7f5f70bea599744e',
#     'artist': 'African Brothers',
#     'title': 'Gimme Gimme African Love',
#     'linked': False},
#    {'uid': '9e6b940a903d07f4f3afff1e31e0f507',
#     'artist': 'Bongwater',
# ...
#     'title': 'Espíritu Santo (Dance)',
#     'linked': False},
#    {'uid': 'b5fb4843ed447673ebf3312f3d688baf',
#     'artist': 'Afronaut Ft.Suheir Hammad',
#     'title': 'Eye Will Not (Naut’s L8 Nite Procession Mix)',
#     'linked': False},
#    {'uid': '5c7e18035a5aa96dd6d9e381b24ef69d',
#     'artist': 'Da Lata (Remix by Bugz In The Attic)',
#     'title': 'Golden (Bugz In The Attic Remix)',
#     'linked': False},
#    {'uid': '80639b72cdf3cd44ab4cf88043af7591',
#     'artist': 'Alphonse',
#     'title': 'Rujac ',
#     'linked': True},
#    {'uid': 'c621d44b841f67c17cd7702c874ef0c5',
#     'artist': 'L’Aroye Ft. Abi Flynn',
#     'title': 'Beauty In Motion',
#     'linked': False},
#    {'uid': '9833da211c13f191607814921ce785fc',
#     'artist': 'Teena Marie',
#     'title': 'You Make Love Like Springtime',
#     'linked': True},
#    {'uid': '1412f044f60a46bcf4c832dd7a3ed974',
#     'artist': 'Ramsey Lewis',
#     'title': 'Spring High',
#     'linked': False},
#    {'uid': 'd5d52f19ab2b47bda5a63eba1f20ad91',
#     'artist': 'Julian Jonah feat. Tamika',
#     'title': 'Now’s The Time For Us',
#     'linked': False},
#    {'uid': '984fa917297cd987be517fcaa26ad5db',
#     'artist': 'Quincy Jones',
#     'title': "Is It Love That We're Missin'",
#     'linked': False},
#    {'uid': '767cc945b66b60a2e1899f6b99934de2',
#     'artist': 'Linda Lewis',
#     'title': 'Gladly Give You My Hand',
#     'linked': False},
#    {'uid': 'd152cd8c39371fd6d4dec7fff025c157',
#     'artist': 'Don Sebesky',
#     'title': 'Fly / Circles',
#     'linked': True}]},
#  'dactylian-and-palo-santo-22nd-may-2023': {'url': '/shows/dactylian-and-palo-santo/episodes/dactylian-and-palo-santo-22nd-may-2023',
#   'name': 'Dactylian & Palo Santo Discos',
#   'loc': 'London',
#   'date': '22.05.23',
#   'tracks': [{'uid': '043486f5b0a947e722da4fc93816c822',
#     'artist': 'Silvio Cesar',
#     'title': 'Levante Os Olhos',
#     'linked': False},
#    {'uid': '0ec1ec779e629780e5c82366f428a9b4',
#     'artist': 'Toquinho E Vinicius',
#     'title': 'No Colo Da Serra',
#     'linked': False},
#    {'uid': '3e5f0f705d87e8269315574fa137076e',
#     'artist': 'Manduka',
#     'title': 'Patria Amada Idolatrada Salve Salve',
#     'linked': False},
#    {'uid': 'ac9cbd996c72c5ddf7d7899de9a8fa2b',
#     'artist': 'Edson Natale',
#     'title': 'Perseguindo O Por Do Sol',
#     'linked': False},
#    {'uid': '24cd024a45c9479a6e73e0c96331c87d',
#     'artist': 'Piry Reis',
#     'title': 'Cisplatina',
#     'linked': True},
#    {'uid': '46ce8fb2e28a0287218a5208d8a52729',
#     'artist': 'Priscilla Ermel',
#     'title': 'Andares',
#     'linked': False},
#    {'uid': '18ae9743658678db8d206e7888b08518',
#     'artist': 'Djalma Corrêa',
#     'title': 'Samba De Ousadia',
#     'linked': False},
#    {'uid': 'cbeb76eb57585b53f015b793f85ea2e5',
#     'artist': 'João Pascoal',
#     'title': 'Força Mediúnica',
#     'linked': False},
#    {'uid': 'a9f05d047e14d42a6e4f5e941eec7278',
#     'artist': 'Wilson Ávila',
#     'title': 'Rei Da Matas - Jesus Cristo é Oxalá - Rei Das Matas',
#     'linked': False},
#    {'uid': 'c8e162846a901f598f700ee08993286a',
#     'artist': 'Jards Macalé',
#     'title': '78 Rotações',
#     'linked': True},
#    {'uid': '54ee12be501b80c7262f6c977f46e6f4',
#     'artist': 'Ronie & Central Do Brasil',
#     'title': 'Essa Maré',
#     'linked': False},
#    {'uid': '0847df80bd900901d26b64c1cc33c143',
#     'artist': 'Sexteto Do Beco',
#     'title': 'Flutuando',
#     'linked': True},
#    {'uid': 'a3e750c0b285147904524a3167ab9426',
#     'artist': 'Grupo Etnia',
#     'title': 'Quarup',
#     'linked': False},
#    {'uid': '2b6ed52a9f108151680c399bb8df88cc',
#     'artist': 'Jaguaribe Carne',
#     'title': 'Outro Tempo',
#     'linked': False},
#    {'uid': 'fdfd25fd2f507db7ce3dbd4f003929b5',
#     'artist': 'Carlos Pinto',
#     'title': 'Ladeira Da Praça',
#     'linked': False},
#    {'uid': 'b07d7f88ca6fe981bc51f193fddcde81',
#     'artist': 'Dionysio E Seu Sexteto',
#     'title': 'Madalena',
#     'linked': False}]},
#  'aldous-rh-22nd-may-2023': {'url': '/shows/aldous-rh/episodes/aldous-rh-22nd-may-2023',
#   'name': 'Aldous RH w/ Plastic Gift - Crammed Discs Special',
#   'loc': 'Manchester',
#   'date': '22.05.23',
#   'tracks': [{'uid': '20693af2861939d22381c687d786a379',
#     'artist': 'Karl Biscuit',
#     'title': 'Hierophone',
#     'linked': True},
#    {'uid': '3d1f56fcc36c926714168e93b7ca3825',
#     'artist': 'Aqsak Maboul',
#     'title': 'Geistige Nacht',
#     'linked': False},
#    {'uid': '738216245f2c16baf09f614a20b1973d',
#     'artist': 'Unknown Arist',
#     'title': 'String Crossing',
#     'linked': False},
#    {'uid': '73e54a4d85a05ae82bee4df063ca3069',
#     'artist': 'Mangugu',
#     'title': 'Strangers In The Day',
#     'linked': False},
#    {'uid': '90b52335d4adbacde1c22371dc4517ca',
#     'artist': 'Des Airs',
#     'title': 'Lovely Lady Of The Roses',
#     'linked': True},
#    {'uid': '1de3640d1bb5a038b584a509d5002d59',
#     'artist': 'The Honeymoon Collage',
#     'title': 'Décollage CGS',
#     'linked': False},
#    {'uid': '6f08ab2d04065ec2c003f32ac92a2bd0',
#     'artist': 'Zazou / Bikaye / Cy 1',
#     'title': 'Mangungu',
#     'linked': False},
#    {'uid': '4aa5b9179bf047460cef4bcffb7b7276',
#     'artist': 'Bel Canto',
#     'title': 'Chaideinoi',
#     'linked': False},
#    {'uid': 'aa68b4adf6d88c2094e75ba6a20dbc90',
#     'artist': 'Karl Biscuit',
#     'title': 'Les Mêmes Histoires',
#     'linked': False},
#    {'uid': '9f702cea52543b5b97d05c9cebbaf531',
#     'artist': 'Vronique Vincent & Aksak Maboul With The Honeymoon Killers',
#     'title': 'I’m Always Crying',
#     'linked': False},
#    {'uid': '632830f567534eefa5dfc3a232de22a4',
#     'artist': 'Blaine L. Reininger, Mikel Rouse',
#     'title': 'West End',
#     'linked': False},
#    {'uid': '5df0f5379e44f8c4823b63ce17ebc762',
#     'artist': 'Daniel Schell & Karo',
#     'title': '3 Moustiquaires',
#     'linked': True},
#    {'uid': 'a4ea0490c75a9b58adbef3268589ef46',
#     'artist': 'Aksak Maboul',
#     'title': 'Le Mur',
#     'linked': False},
#    {'uid': '053eb0e30f9b7034b7e86eb4ab86a9cc',
#     'artist': 'Tuxedomoon',
#     'title': 'Toreador Del Amor',
#     'linked': True},
#    {'uid': '276a2f921d5b8bf2803e52e8ee98c605',
#     'artist': 'Marc Hollander, Aksak Maboul',
#     'title': 'Chanter Est Sain',
#     'linked': False},
#    {'uid': '3aebdd5627b520df7d0d6a859d442561',
#     'artist': 'Tuxedomoon / Cult With No Name',
#     'title': 'Lincoln Street',
#     'linked': False},
#    {'uid': '05c205cd064d36db382da19bbd127336',
#     'artist': 'Hector Zazou',
#     'title': 'Youth',
#     'linked': False},
#    {'uid': '571569ded0ca25593ee74c3845285378',
#     'artist': 'Des Airs',
#     'title': 'Ling',
#     'linked': True},
#    {'uid': 'ec0e3007791eb2a5a531da1ab6f64c7f',
#     'artist': 'Hermine',
#     'title': 'I Won’t Make It Without You',
#     'linked': True}]},
#  'soup-to-nuts-john-gomez-22nd-may-2023': {'url': '/shows/soup-to-nuts-john-gomez/episodes/soup-to-nuts-john-gomez-22nd-may-2023',
#   'name': 'Soup To Nuts w/ John Gómez',
#   'loc': 'London',
#   'date': '22.05.23',
#   'tracks': [{'uid': '7154d6095b53fbf7e2e389b73c6dae20',
#     'artist': 'Pedro Ricardo, Damian Botigue',
#     'title': 'Como El Viento',
#     'linked': False},
#    {'uid': 'ff43aecbbde9fbb7a07839f1c8148864',
#     'artist': 'Lapa Dula',
#     'title': 'Sibilla',
#     'linked': False},
#    {'uid': '5885ea3fa97ee95faa69f2f68232f948',
#     'artist': 'Donald Byrd & 125th Street, N.Y.C.',
#     'title': 'I Love Your Love',
#     'linked': False},
#    {'uid': '234879cdaaefc01da719bb21886c0fbe',
#     'artist': 'Prince Baju',
#     'title': 'Life Is A Mission',
#     'linked': False},
#    {'uid': '8f47633fd439d6995603ca8e7f5f946e',
#     'artist': 'Cucumberman',
#     'title': 'Possessor',
#     'linked': False},
#    {'uid': 'd6cf35e25eeb2d4c229b80f566e57759',
#     'artist': '7Fo',
#     'title': 'ヒーリング剣=Healing Sword',
#     'linked': True},
#    {'uid': '9537db5b0a664839aeaa2e116737736d',
#     'artist': 'Turn On The Sunlight',
#     'title': 'Naturally (Photay Remix)',
#     'linked': False},
#    {'uid': '23ea20cbeb64e1f63fc8c2063b7f431d',
#     'artist': 'Buddy Don',
#     'title': 'DuppyKilla',
#     'linked': False},
#    {'uid': 'df70f77297d410fc33545b7e40f0b9a5',
#     'artist': 'Negra Branca',
#     'title': 'O Anzol',
#     'linked': False},
#    {'uid': '78b37174620b4b917622ce6c54797087',
#     'artist': 'Samuele Strufaldi',
#     'title': 'Abodan',
#     'linked': False},
#    {'uid': '67cb6f2baa9f2992fc20c3daaaab0ece',
#     'artist': 'Pedro Ricardo & Damián Botigué',
#     'title': 'Ja Foi Ja Nao Deu',
#     'linked': False},
#    {'uid': 'b5b85830a248ef8f1c922aae04a12907',
#     'artist': 'Frank Harris & Maria Marquez',
#     'title': 'Down By The Rio (Frakas Remix)',
#     'linked': True},
#    {'uid': 'ca450402ba87d9e9d8550eb4a209457c',
#     'artist': 'Elmer',
#     'title': 'Hvorfor Ikke Mig',
#     'linked': True},
#    {'uid': 'b3b4f64d5cfb59db2cd3a551d5c5f698',
#     'artist': 'Kenny Keys',
#     'title': 'Born To Love (Feat. Nina Rae)',
#     'linked': False},
#    {'uid': '7fc10e3528c44005cd5b676b55474dcc',
#     'artist': 'Jorge Ben Jor',
#     'title': 'Cowboy George',
#     'linked': False},
#    {'uid': '83b6c833e8a865917f94e736b9db207e',
#     'artist': 'MSD',
#     'title': 'The Grind',
#     'linked': False},
#    {'uid': 'e7de709aba132a98b6a22541922c0c13',
#     'artist': 'Craig Sherard',
#     'title': 'See The Stars Feat. Amp Fiddler',
#     'linked': False},
#    {'uid': '912d08253dff1bc0eabcc2d4e890040f',
#     'artist': 'Tess Ivie',
#     'title': 'I Let Love (Make A Fool Out Of Me)',
#     'linked': False},
#    {'uid': 'ce2e5b58afc0c8b48d49f8afda5551a6',
#     'artist': 'Ara Macao',
#     'title': 'Canyon',
#     'linked': True},
#    {'uid': '6bc196a2d040106fbabbd016989464b2',
#     'artist': 'Ms Ray',
#     'title': 'Broken Heart Still Beats',
#     'linked': True},
#    {'uid': 'ad98db9aa58226a08051fd3d7cb8642d',
#     'artist': 'KNOWER',
#     'title': "I'm The President",
#     'linked': False},
#    {'uid': '36106e523f4e4dd6d5b69eaa9223354b',
#     'artist': 'Cyril Cyril & Meridian Brothers',
#     'title': 'Diablos De Chuao',
#     'linked': False},
#    {'uid': '31acd59f9d6fa21c7875c4126d92f920',
#     'artist': 'Nebraska',
#     'title': 'Love Is Hate',
#     'linked': False},
#    {'uid': '7cb57453b7d42ab369da3d4bd987160d',
#     'artist': 'DESKTOPICON',
#     'title': 'WISH YOU WERE HERE',
#     'linked': False},
#    {'uid': '3753b05782e950347d3432f7f085f339',
#     'artist': 'J Walker',
#     'title': 'Salmon',
#     'linked': False},
#    {'uid': 'fc9577e6f817986303f009fa4d3fcd0b',
#     'artist': 'Gigi Testa',
#     'title': 'Malinke',
#     'linked': False},
#    {'uid': '1574df2e2ab6440f7a7580f24d3d604e',
#     'artist': 'Zeitgeist Freedom Energy Exchange',
#     'title': 'Bleached',
#     'linked': False},
#    {'uid': '8815ed88a3ca18186f906a572a8b72c0',
#     'artist': 'Barney Willen',
#     'title': 'Zombizar',
#     'linked': False}]},
#  'anthonychalmers-22nd-may-2023': {'url': '/shows/anthonychalmers/episodes/anthonychalmers-22nd-may-2023',
#   'name': 'Anthony Chalmers',
#   'loc': 'London',
#   'date': '22.05.23',
#   'tracks': [{'uid': '3489136b096f02d15ab0685ac59de1c7',
#     'artist': 'Sly & Robbie',
#     'title': 'Assault On Station 5',
#     'linked': False},
#    {'uid': '672d419fc86a099811610c591dece95e',
#     'artist': 'Black Uhuru',
#     'title': 'General Penititary',
#     'linked': False},
#    {'uid': 'fd2ed7c7d2d773343b7419b2b036f3da',
#     'artist': 'Meridian brothers',
#     'title': 'Cumbia De La Fuente',
#     'linked': True},
#    {'uid': '1ed9d830fe1ffbd5aa3d61e7944776c3',
#     'artist': 'Tim Maia',
#     'title': 'Quer Queira Quer Nao Queira',
#     'linked': False},
#    {'uid': '2eaf82d59657b3a5b4242098a828439c',
#     'artist': 'Part Chimp',
#     'title': "Bouncer's Dream",
#     'linked': False},
#    {'uid': 'a34097cdc549968e3ecfbcb7c49b37c5',
#     'artist': 'Oneida',
#     'title': 'Low Tide',
#     'linked': True},
#    {'uid': '0ca31e64c5edbf612eca062860608108',
#     'artist': 'Och',
#     'title': 'Bolid ',
#     'linked': False},
#    {'uid': '84df7da312b522bb910c5cfc7f4e63ac',
#     'artist': 'Katie Gately',
#     'title': 'Fawn',
#     'linked': True},
#    {'uid': '7f4d31badf96f5277c400be27236c15c',
#     'artist': 'Paradise Bangkok Molam Band',
#     'title': 'Roob Lor Pu Tai',
#     'linked': False},
#    {'uid': 'ac54721446b4b5bad5a195c0c390b1cb',
#     'artist': 'Civilistjavel Feat. Cucina Povera',
#     'title': 'Louhivesi',
#     'linked': False},
#    {'uid': 'abe1719e02c687c90ce7ee777c825f84',
#     'artist': 'Acid Mothers Temple, Rosina De Peira',
#     'title': 'Pink Lady Lemonade',
#     'linked': True}]},
#  'the-breakfast-show-flo-22nd-may-2023': {'url': '/shows/the-breakfast-show-flo/episodes/the-breakfast-show-flo-22nd-may-2023',
#   'name': 'The NTS Breakfast Show w/ Flo',
#   'loc': 'London',
#   'date': '22.05.23',
#   'tracks': [{'uid': '5e4824980f9e3694263aeb1d24ba2bc9',
#     'artist': 'Sam Prekop',
#     'title': 'A Cloud To The Back',
#     'linked': True},
#    {'uid': 'c29ada76d8f79ae1d0453e1c6b99dd74',
#     'artist': 'Broadcast',
#     'title': 'Unchanging Window',
#     'linked': False},
#    {'uid': 'cc89bcdcb6c6f95c990c9b69828d2144',
#     'artist': 'Electrelane',
#     'title': 'Enter Laughing',
#     'linked': True},
#    {'uid': '49470e43d5d801320d44eb7cab1f0d44',
#     'artist': 'The Stone Roses',
#     'title': 'Shoot You Down',
#     'linked': True},
#    {'uid': '3c8ab6fe55cdb05f5a4a0548ef9ca700',
#     'artist': 'T. Rex',
#     'title': 'By The Light Of A Magical Moon',
#     'linked': True},
#    {'uid': '9fdcab9844ca0999fdb7512a8f78fcf1',
#     'artist': 'Helen',
#     'title': 'Right Outside',
#     'linked': True},
#    {'uid': '486c6a5c92dd093226f3d97c29372f29',
#     'artist': 'J.J. Cale',
#     'title': 'Cocaine',
#     'linked': False},
#    {'uid': '1ee684015152eba58db27701ed2a496d',
#     'artist': 'The Field Mice',
#     'title': 'Fabulous Friend',
#     'linked': True},
#    {'uid': '00a1b7101c588519ac2676e27f7ec3cf',
#     'artist': 'Ashra',
#     'title': 'Oasis',
#     'linked': True},
#    {'uid': 'd0ad2b8df6020de5e799a0d5ac916e55',
#     'artist': 'Steve Hillage',
#     'title': 'Alone',
#     'linked': True},
#    {'uid': '8795cac52e960c3f1c919a06bde49411',
#     'artist': 'Spacemen 3',
#     'title': 'Come Down Softly To My Soul',
#     'linked': True},
#    {'uid': 'cc9295b49560f6c06365bba562911605',
#     'artist': 'Shoes',
#     'title': 'Do I Get So Shy',
#     'linked': True},
#    {'uid': 'f3f02e289c91d6cc6501eaf52ac94495',
#     'artist': 'Nancy Sinatra',
#     'title': 'Kinky Love',
#     'linked': False},
#    {'uid': '414c6674ad2d7ba35a58c321d32a6531',
#     'artist': 'Roxy Music',
#     'title': 'The Space Between',
#     'linked': True},
#    {'uid': '3b499b81b71900107b6e0e8586cedfbb',
#     'artist': 'The Durutti Column',
#     'title': 'For Belgain Friends',
#     'linked': False},
#    {'uid': '2c8c6ad4c906100a54290d9c43ee91ce',
#     'artist': 'Spacemen 3',
#     'title': 'I Love You',
#     'linked': True},
#    {'uid': '42ef87807ef742689a44000f1c0a7e6a',
#     'artist': 'Chris And Cosey',
#     'title': 'Exotika',
#     'linked': True},
#    {'uid': '62af120e62e8faee24be9107cce4c84a',
#     'artist': 'Barracuda',
#     'title': 'I Feel So Down',
#     'linked': True},
#    {'uid': '98b75ae728401f56f41e246654e5c01a',
#     'artist': 'The Cleaners From Venus',
#     'title': 'Gamma Ray Blue',
#     'linked': True},
#    {'uid': '1bbc28b1dfbbeb07651ceafa671476e5',
#     'artist': 'Joni Mitchell',
#     'title': "You Turn Me On, I'm A Radio",
#     'linked': True},
#    {'uid': '5d15798353de1433afc2d0f9508eb9de',
#     'artist': 'Susan Cadogan',
#     'title': 'Cause You Love Me Baby',
#     'linked': True},
#    {'uid': 'cb3de1669278404b52333963340e9715',
#     'artist': 'Kraftwerk',
#     'title': 'Klingklang',
#     'linked': True},
#    {'uid': '8a0b2d2092689c9a39950ebd7e5bb937',
#     'artist': 'Ya Ya Choral',
#     'title': 'Waiting Time',
#     'linked': True},
#    {'uid': '9dffc86f654660d739fb8587da9d5f7c',
#     'artist': 'Minami Deutsch',
#     'title': 'Still Foggy',
#     'linked': True},
#    {'uid': 'd5045c83649b3e34053708a35a99e41b',
#     'artist': 'Sardine V',
#     'title': 'Stuck On You',
#     'linked': True},
#    {'uid': 'eb297e792d2a6f586f7ebfb967757761',
#     'artist': 'Charmels',
#     'title': 'I’ve Done It Again',
#     'linked': False},
#    {'uid': 'b170f09dbb19b2499411229a7ae7980d',
#     'artist': 'Patrice Rushen',
#     'title': 'Remind Me',
#     'linked': True}]},
#  ...}
